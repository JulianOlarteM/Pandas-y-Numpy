# %%
import numpy as np

# %%
arr = np.random.randint(1,10 ,(3,2))
print(arr)
# Out:
# [[9 2]
#  [8 8]
#  [3 2]]

# %% [markdown]
# cuantas cantidades tendo por cada dimencion:

# %%
arr.shape
# Out:
# (3, 2)

# %% [markdown]
# para reacomodar el arreglo es posible:

# %%
arr.reshape(1,6)
# Out:
# array([[9, 2, 8, 8, 3, 2]])

# %%
arr.reshape(2,3)
# Out:
# array([[9, 2, 8],
#        [8, 3, 2]])

# %% [markdown]
# otra manera de escribit lo mismo:

# %%
np.reshape(arr , (1,6))
# Out:
# array([[9, 2, 8, 8, 3, 2]])

# %% [markdown]
# Como hacemos si queremos hacer el reshape pero con un orden distinto?

# %%
arr
# Out:
# array([[9, 2],
#        [8, 8],
#        [3, 2]])

# %%
np.reshape(arr, (2,3), 'C')
# Out:
# array([[9, 2, 8],
#        [8, 3, 2]])

# %%
np.reshape(arr, (2,3), 'F')
# Out:
# array([[9, 3, 8],
#        [8, 2, 2]])

# %%
np.reshape(arr, (2,3), 'A')
# Out:
# array([[9, 2, 8],
#        [8, 3, 2]])
