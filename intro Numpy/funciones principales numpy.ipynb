# %%
import numpy as np

# %% [markdown]
# Creamos una array y una matriz:

# %%
arr = np.random.randint(1,20,10)
arr
# Out:
# array([13, 16, 13,  1,  5,  5,  4,  1, 14,  2])

# %%
matriz = arr.reshape(2,5)
matriz
# Out:
# array([[13, 16, 13,  1,  5],
#        [ 5,  4,  1, 14,  2]])

# %% [markdown]
# Funcion Max():

# %%
arr.max()
# Out:
# 16

# %%
matriz.max()
# Out:
# 16

# %% [markdown]
# Para determinar el maximo por columanas

# %%
matriz.max(0)
# Out:
# array([13, 16, 13, 14,  5])

# %% [markdown]
# para determinar el maximo por filas

# %%
matriz.max(1)
# Out:
# array([16, 14])

# %% [markdown]
# Como saber cual es el indice de nuestros valor maximo?

# %%
arr.argmax()
# Out:
# 1

# %%
matriz.argmax(0)
# Out:
# array([0, 0, 0, 1, 0])

# %%
matriz.argmax(1)
# Out:
# array([1, 3])

# %% [markdown]
# tambien exite la funcion min ():
# Podemos realizar todo lo anterior.

# %%
arr.min()
# Out:
# 1

# %%
matriz.min(0)
# Out:
# array([5, 4, 1, 1, 2])

# %%
matriz.argmin(1)
# Out:
# array([3, 2])

# %% [markdown]
# Como saber cuanta distancia ahi desde el valor minimo al valor maximo ? funcion ptp() (de pico a pico)

# %%
arr
# Out:
# array([13, 16, 13,  1,  5,  5,  4,  1, 14,  2])

# %%
arr.ptp()
# Out:
# 15

# %%
matriz
# Out:
# array([[13, 16, 13,  1,  5],
#        [ 5,  4,  1, 14,  2]])

# %%
matriz.ptp(0)
# Out:
# array([ 8, 12, 12, 13,  3])

# %%
matriz.ptp(1)
# Out:
# array([15, 13])

# %% [markdown]
# Organizamos el arr y sacamos percentiles:

# %%
arr
# Out:
# array([13, 16, 13,  1,  5,  5,  4,  1, 14,  2])

# %%
arr.sort()
arr
# Out:
# array([ 1,  1,  2,  4,  5,  5, 13, 13, 14, 16])

# %%
np.percentile(arr,50)
# Out:
# 5.0

# %%
np.percentile(arr,0)
# Out:
# 1.0

# %%
np.percentile(arr,100)
# Out:
# 16.0

# %% [markdown]
# Mediana y desviacion estandar, varianza, media

# %%
np.median(arr)
# Out:
# 5.0

# %%
np.median(matriz, 0)
# Out:
# array([ 3. ,  7. ,  7.5,  9. , 10.5])

# %%
np.median(matriz, 1)
# Out:
# array([ 2., 13.])

# %%
np.std(arr)**2
# Out:
# 31.439999999999994

# %%
np.var(arr)
# Out:
# 31.439999999999998

# %%
np.mean(arr)
# Out:
# 7.4

# %%
np.mean(matriz , 0)
# Out:
# array([ 3. ,  7. ,  7.5,  9. , 10.5])

# %% [markdown]
# Concatenacion:

# %%
a = np.array([[1,2],[3,4]])
b = np.array([5,6])

# %%
np.concatenate((a,b),axis = 0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-111-140319de9b9e> in <module>()
# ----> 1 np.concatenate((a,b),axis = 0)
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# ValueError: all the input arrays must have same number of dimensions, but the array at index 0 has 2 dimension(s) and the array at index 1 has 1 dimension(s)

# %%
a.ndim
# Out:
# 2

# %%
b.ndim
# Out:
# 1

# %%
b = np.expand_dims(b,axis=0)

# %%
b.ndim
# Out:
# 2

# %%
np.concatenate((a,b),axis= 0)
# Out:
# array([[1, 2],
#        [3, 4],
#        [5, 6]])

# %%
np.concatenate((a,b),axis=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-117-644816af0704> in <module>()
# ----> 1 np.concatenate((a,b),axis=1)
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# ValueError: all the input array dimensions for the concatenation axis must match exactly, but along dimension 0, the array at index 0 has size 2 and the array at index 1 has size 1

# %%
np.concatenate((a,b.T),axis=1)
# Out:
# array([[1, 2, 5],
#        [3, 4, 6]])
